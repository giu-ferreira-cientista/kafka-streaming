# %%
# notification_consumer.py
from kafka import KafkaConsumer, KafkaProducer
import os
import json
import uuid
from concurrent.futures import ThreadPoolExecutor
TOPIC_NAME = "NOTIFICATION"
KAFKA_SERVER = "kafka:29092"

# %%
consumer = KafkaConsumer(
    TOPIC_NAME,
    bootstrap_servers=[KAFKA_SERVER],
    enable_auto_commit=False,
    # to deserialize kafka.producer.object into dict
    #value_deserializer=lambda m: json.loads(m.decode('utf-8')),
)

# %%
def sendNotification(data):
	# process steps
    print(data)
    json_data = json.loads(data)

    if(json_data['avgbpm'] >= 120):
        print("\nALERTA RECEBIDO! Cheque seus batimentos cardiacos! (BPM >= 120)\n")

    if(json_data['avgtemp'] >= 38):
        print("\nALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)\n")

    #if(json_data['avgpressao'] >= 13):
    #    print("\nALERTA RECEBIDO! Cheque sua pressao! (P >= 13)\n")

    #if(json_data['avgrespiracao'] >= 20):
    #    print("\nALERTA RECEBIDO! Cheque sua frequencia respiratoria! (F >= 20)\n")

    #if(json_data['avgglicemia'] >= 100):
    #    print("\nALERTA RECEBIDO! Cheque sua glicemia! (G >= 100)\n")

    #if(json_data['avgsaturacao_oxigenio'] <= 94):
    #    print("\nALERTA RECEBIDO! Cheque sua saturação do oxigenio! (S <= 94)\n")

# %%
for notification in consumer:
    
    print(notification.value)
    notification_data = notification.value
    sendNotification(notification_data)
# Out:
# b'{"eventTime":"2022-03-02 06:45:00","nome":"maria","avgbpm":77.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-02 06:45:00","nome":"maria","avgbpm":77.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-02 20:00:00","nome":"antonio","avgbpm":40.0,"avgtemp":40.0}'
# b'{"eventTime":"2022-03-02 20:00:00","nome":"antonio","avgbpm":40.0,"avgtemp":40.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-03 01:20:00","nome":"antonio","avgbpm":96.0,"avgtemp":41.0}'
# b'{"eventTime":"2022-03-03 01:20:00","nome":"antonio","avgbpm":96.0,"avgtemp":41.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-03 01:45:00","nome":"maria","avgbpm":82.0,"avgtemp":42.0}'
# b'{"eventTime":"2022-03-03 01:45:00","nome":"maria","avgbpm":82.0,"avgtemp":42.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-03 05:10:00","nome":"joao","avgbpm":70.0,"avgtemp":40.0}'
# b'{"eventTime":"2022-03-03 05:10:00","nome":"joao","avgbpm":70.0,"avgtemp":40.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-04 08:55:00","nome":"maria","avgbpm":92.0,"avgtemp":40.0}'
# b'{"eventTime":"2022-03-04 08:55:00","nome":"maria","avgbpm":92.0,"avgtemp":40.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-04 16:10:00","nome":"joao","avgbpm":86.0,"avgtemp":40.0}'
# b'{"eventTime":"2022-03-04 16:10:00","nome":"joao","avgbpm":86.0,"avgtemp":40.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-04 23:25:00","nome":"joao","avgbpm":138.0,"avgtemp":34.0}'
# b'{"eventTime":"2022-03-04 23:25:00","nome":"joao","avgbpm":138.0,"avgtemp":34.0}'
#
# ALERTA RECEBIDO! Cheque seus batimentos cardiacos! (BPM >= 120)
#
# b'{"eventTime":"2022-03-09 02:15:00","nome":"maria","avgbpm":73.0,"avgtemp":40.0}'
# b'{"eventTime":"2022-03-09 02:15:00","nome":"maria","avgbpm":73.0,"avgtemp":40.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-09 07:20:00","nome":"maria","avgbpm":89.0,"avgtemp":41.0}'
# b'{"eventTime":"2022-03-09 07:20:00","nome":"maria","avgbpm":89.0,"avgtemp":41.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-09 13:00:00","nome":"joao","avgbpm":84.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-09 13:00:00","nome":"joao","avgbpm":84.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-10 20:50:00","nome":"joao","avgbpm":105.0,"avgtemp":40.0}'
# b'{"eventTime":"2022-03-10 20:50:00","nome":"joao","avgbpm":105.0,"avgtemp":40.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-10 21:15:00","nome":"joao","avgbpm":95.0,"avgtemp":42.0}'
# b'{"eventTime":"2022-03-10 21:15:00","nome":"joao","avgbpm":95.0,"avgtemp":42.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-11 06:40:00","nome":"joao","avgbpm":76.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-11 06:40:00","nome":"joao","avgbpm":76.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-11 10:05:00","nome":"antonio","avgbpm":75.0,"avgtemp":40.0}'
# b'{"eventTime":"2022-03-11 10:05:00","nome":"antonio","avgbpm":75.0,"avgtemp":40.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-11 14:15:00","nome":"joao","avgbpm":113.0,"avgtemp":42.0}'
# b'{"eventTime":"2022-03-11 14:15:00","nome":"joao","avgbpm":113.0,"avgtemp":42.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-11 20:55:00","nome":"antonio","avgbpm":121.0,"avgtemp":35.0}'
# b'{"eventTime":"2022-03-11 20:55:00","nome":"antonio","avgbpm":121.0,"avgtemp":35.0}'
#
# ALERTA RECEBIDO! Cheque seus batimentos cardiacos! (BPM >= 120)
#
# b'{"eventTime":"2022-03-13 18:20:00","nome":"joao","avgbpm":77.0,"avgtemp":41.0}'
# b'{"eventTime":"2022-03-13 18:20:00","nome":"joao","avgbpm":77.0,"avgtemp":41.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-15 01:05:00","nome":"antonio","avgbpm":70.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-15 01:05:00","nome":"antonio","avgbpm":70.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-16 10:00:00","nome":"antonio","avgbpm":78.0,"avgtemp":42.0}'
# b'{"eventTime":"2022-03-16 10:00:00","nome":"antonio","avgbpm":78.0,"avgtemp":42.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-16 19:50:00","nome":"antonio","avgbpm":106.0,"avgtemp":40.0}'
# b'{"eventTime":"2022-03-16 19:50:00","nome":"antonio","avgbpm":106.0,"avgtemp":40.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-18 00:10:00","nome":"antonio","avgbpm":53.0,"avgtemp":40.0}'
# b'{"eventTime":"2022-03-18 00:10:00","nome":"antonio","avgbpm":53.0,"avgtemp":40.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-18 10:15:00","nome":"antonio","avgbpm":72.0,"avgtemp":42.0}'
# b'{"eventTime":"2022-03-18 10:15:00","nome":"antonio","avgbpm":72.0,"avgtemp":42.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-19 23:25:00","nome":"joao","avgbpm":63.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-19 23:25:00","nome":"joao","avgbpm":63.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-20 14:00:00","nome":"joao","avgbpm":107.0,"avgtemp":40.0}'
# b'{"eventTime":"2022-03-20 14:00:00","nome":"joao","avgbpm":107.0,"avgtemp":40.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-21 05:00:00","nome":"maria","avgbpm":80.0,"avgtemp":41.0}'
# b'{"eventTime":"2022-03-21 05:00:00","nome":"maria","avgbpm":80.0,"avgtemp":41.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-21 11:35:00","nome":"maria","avgbpm":102.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-21 11:35:00","nome":"maria","avgbpm":102.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-21 12:50:00","nome":"maria","avgbpm":81.0,"avgtemp":42.0}'
# b'{"eventTime":"2022-03-21 12:50:00","nome":"maria","avgbpm":81.0,"avgtemp":42.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-23 06:20:00","nome":"antonio","avgbpm":124.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-23 06:20:00","nome":"antonio","avgbpm":124.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque seus batimentos cardiacos! (BPM >= 120)
#
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-24 17:40:00","nome":"antonio","avgbpm":97.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-24 17:40:00","nome":"antonio","avgbpm":97.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-27 00:10:00","nome":"maria","avgbpm":98.0,"avgtemp":42.0}'
# b'{"eventTime":"2022-03-27 00:10:00","nome":"maria","avgbpm":98.0,"avgtemp":42.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-28 11:45:00","nome":"antonio","avgbpm":71.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-28 11:45:00","nome":"antonio","avgbpm":71.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-28 21:15:00","nome":"maria","avgbpm":82.0,"avgtemp":42.0}'
# b'{"eventTime":"2022-03-28 21:15:00","nome":"maria","avgbpm":82.0,"avgtemp":42.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-29 02:45:00","nome":"antonio","avgbpm":57.0,"avgtemp":41.0}'
# b'{"eventTime":"2022-03-29 02:45:00","nome":"antonio","avgbpm":57.0,"avgtemp":41.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-29 05:30:00","nome":"antonio","avgbpm":124.0,"avgtemp":35.0}'
# b'{"eventTime":"2022-03-29 05:30:00","nome":"antonio","avgbpm":124.0,"avgtemp":35.0}'
#
# ALERTA RECEBIDO! Cheque seus batimentos cardiacos! (BPM >= 120)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-c5fb030429e4> in <module>
# ----> 1 for notification in consumer:
#       2
#       3     print(notification.value)
#       4     notification_data = notification.value
#       5     sendNotification(notification_data)
#
# /opt/conda/lib/python3.9/site-packages/kafka/consumer/group.py in __next__(self)
#    1191             return self.next_v1()
#    1192         else:
# -> 1193             return self.next_v2()
#    1194
#    1195     def next_v2(self):
#
# /opt/conda/lib/python3.9/site-packages/kafka/consumer/group.py in next_v2(self)
#    1199                 self._iterator = self._message_generator_v2()
#    1200             try:
# -> 1201                 return next(self._iterator)
#    1202             except StopIteration:
#    1203                 self._iterator = None
#
# /opt/conda/lib/python3.9/site-packages/kafka/consumer/group.py in _message_generator_v2(self)
#    1114     def _message_generator_v2(self):
#    1115         timeout_ms = 1000 * (self._consumer_timeout - time.time())
# -> 1116         record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1117         for tp, records in six.iteritems(record_map):
#    1118             # Generators are stateful, and it is possible that the tp / records
#
# /opt/conda/lib/python3.9/site-packages/kafka/consumer/group.py in poll(self, timeout_ms, max_records, update_offsets)
#     653         remaining = timeout_ms
#     654         while True:
# --> 655             records = self._poll_once(remaining, max_records, update_offsets=update_offsets)
#     656             if records:
#     657                 return records
#
# /opt/conda/lib/python3.9/site-packages/kafka/consumer/group.py in _poll_once(self, timeout_ms, max_records, update_offsets)
#     700
#     701         timeout_ms = min(timeout_ms, self._coordinator.time_to_next_poll() * 1000)
# --> 702         self._client.poll(timeout_ms=timeout_ms)
#     703         # after the long poll, we should check whether the group needs to rebalance
#     704         # prior to returning data so that the group can stabilize faster
#
# /opt/conda/lib/python3.9/site-packages/kafka/client_async.py in poll(self, timeout_ms, future)
#     600                     timeout = max(0, timeout)  # avoid negative timeouts
#     601
# --> 602                 self._poll(timeout / 1000)
#     603
#     604             # called without the lock to avoid deadlock potential
#
# /opt/conda/lib/python3.9/site-packages/kafka/client_async.py in _poll(self, timeout)
#     632
#     633         start_select = time.time()
# --> 634         ready = self._selector.select(timeout)
#     635         end_select = time.time()
#     636         if self._sensors:
#
# /opt/conda/lib/python3.9/selectors.py in select(self, timeout)
#     467             ready = []
#     468             try:
# --> 469                 fd_event_list = self._selector.poll(timeout, max_ev)
#     470             except InterruptedError:
#     471                 return ready
#
# KeyboardInterrupt:
